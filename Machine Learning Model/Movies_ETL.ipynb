# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import ast
import json
import time
from datetime import datetime

# %%
movies_original = pd.read_csv("movies_dataset.csv")
movies_original.head()
# Out:
# /tmp/ipykernel_11909/352882099.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies_original = pd.read_csv("movies_dataset.csv")
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %% [markdown]
# Lo primero será desanidar los datos en las columnas anidadas, iniciando por:
# ### belongs_to_collection
#
# Esto se consigue usando la librería `ast`, la cual nos permite analizar y trabajar con árboles, lo que en este proyecto se traduce a poder manejar más fácilmente los diccionarios que estaban en un inicio en formato `string`

# %%
movies_copy = movies_original.copy()

# toma los valores que están inicialmente como strings y los transforma en diccionarios
series_from_col = movies_copy["belongs_to_collection"].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
series_from_col.head(5)
# Out:
# 0    {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                  NaN
# 2    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                  NaN
# 4    {'id': 96871, 'name': 'Father of the Bride Col...
# Name: belongs_to_collection, dtype: object

# %%
unnested_dataframe = pd.json_normalize(series_from_col)
result_dataframe = pd.concat([movies_copy.drop(columns=['belongs_to_collection']), unnested_dataframe], axis=1)
result_dataframe.head(5)
# Out:
#    adult    budget                                             genres  \
# 0  False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4  False         0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview popularity  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943  ...
# 1  When siblings Judy and Peter discover an encha...  17.015539  ...
# 2  A family wedding reignites the ancient feud be...    11.7129  ...
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495  ...
# 4  Just when George Banks has recovered from his ...   8.387519  ...
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video  vote_average  vote_count        id  \
# 0                    Toy Story  False           7.7      5415.0   10194.0
# 1                      Jumanji  False           6.9      2413.0       NaN
# 2             Grumpier Old Men  False           6.5        92.0  119050.0
# 3            Waiting to Exhale  False           6.1        34.0       NaN
# 4  Father of the Bride Part II  False           5.7       173.0   96871.0
#
#                              name                       poster_path  \
# 0            Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
# 1                             NaN                               NaN
# 2       Grumpy Old Men Collection  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg
# 3                             NaN                               NaN
# 4  Father of the Bride Collection  /nts4iOmNnq7GNicycMJ9pSAn204.jpg
#
#                       backdrop_path
# 0  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1                               NaN
# 2  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
# 3                               NaN
# 4  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg
#
# [5 rows x 27 columns]

# %% [markdown]
# ### genres
#
# Esta columna también debe desanidarse

# %%
dataframe_from_col2 = pd.DataFrame(columns=['genre_id','genre_name'])

for value in result_dataframe["genres"]:
  data = ast.literal_eval(value)
  ids = [item['id'] for item in data]
  names = [item['name'] for item in data]
  dataframe_from_col2.loc[len(dataframe_from_col2)] = [ids,names]

dataframe_from_col2.head(5)
# Out:
#           genre_id                    genre_name
# 0  [16, 35, 10751]   [Animation, Comedy, Family]
# 1  [12, 14, 10751]  [Adventure, Fantasy, Family]
# 2      [10749, 35]             [Romance, Comedy]
# 3  [35, 18, 10749]      [Comedy, Drama, Romance]
# 4             [35]                      [Comedy]

# %%
result_dataframe = result_dataframe.join(dataframe_from_col2)
result_dataframe.head(5)
# Out:
#    adult    budget                                             genres  \
# 0  False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4  False         0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview popularity  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943  ...
# 1  When siblings Judy and Peter discover an encha...  17.015539  ...
# 2  A family wedding reignites the ancient feud be...    11.7129  ...
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495  ...
# 4  Just when George Banks has recovered from his ...   8.387519  ...
#
#                          title  video vote_average vote_count        id  \
# 0                    Toy Story  False          7.7     5415.0   10194.0
# 1                      Jumanji  False          6.9     2413.0       NaN
# 2             Grumpier Old Men  False          6.5       92.0  119050.0
# 3            Waiting to Exhale  False          6.1       34.0       NaN
# 4  Father of the Bride Part II  False          5.7      173.0   96871.0
#
#                              name                       poster_path  \
# 0            Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
# 1                             NaN                               NaN
# 2       Grumpy Old Men Collection  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg
# 3                             NaN                               NaN
# 4  Father of the Bride Collection  /nts4iOmNnq7GNicycMJ9pSAn204.jpg
#
#                       backdrop_path         genre_id  \
# 0  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg  [16, 35, 10751]
# 1                               NaN  [12, 14, 10751]
# 2  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg      [10749, 35]
# 3                               NaN  [35, 18, 10749]
# 4  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg             [35]
#
#                      genre_name
# 0   [Animation, Comedy, Family]
# 1  [Adventure, Fantasy, Family]
# 2             [Romance, Comedy]
# 3      [Comedy, Drama, Romance]
# 4                      [Comedy]
#
# [5 rows x 29 columns]

# %% [markdown]
# ### production_companies
#
# Esta es la siguiente columna a desanidar. Se procederá de igual forma que con la columna genres. Aunque lo ideal sería crear una función, aún no comprendo bien el funcionamiento de la librerías `ast` por lo que debo evaluarla para cada columna

# %%
dataframe_from_col3 = pd.DataFrame(columns=['production_company_name','production_company_id'])

for value in result_dataframe["production_companies"]:
    if pd.notna(value):  # Check if the value is not NaN
        data = ast.literal_eval(value)
        if isinstance(data, list) and len(data) > 0:
            ids = [item['id'] for item in data]
            names = [item['name'] for item in data]
            dataframe_from_col3.loc[len(dataframe_from_col3)] = [names, ids]
        else:
            dataframe_from_col3.loc[len(dataframe_from_col3)] = [None, None]
    else:
        dataframe_from_col3.loc[len(dataframe_from_col3)] = [None, None]

dataframe_from_col3.head(5)
# Out:
#                              production_company_name production_company_id
# 0                          [Pixar Animation Studios]                   [3]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...    [559, 2550, 10201]
# 2                     [Warner Bros., Lancaster Gate]         [6194, 19464]
# 3           [Twentieth Century Fox Film Corporation]                 [306]
# 4       [Sandollar Productions, Touchstone Pictures]          [5842, 9195]

# %%
result_dataframe=result_dataframe.join(dataframe_from_col3)
result_dataframe.head(5)
# Out:
#    adult    budget                                             genres  \
# 0  False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4  False         0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview popularity  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943  ...
# 1  When siblings Judy and Peter discover an encha...  17.015539  ...
# 2  A family wedding reignites the ancient feud be...    11.7129  ...
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495  ...
# 4  Just when George Banks has recovered from his ...   8.387519  ...
#
#   vote_average vote_count        id                            name  \
# 0          7.7     5415.0   10194.0            Toy Story Collection
# 1          6.9     2413.0       NaN                             NaN
# 2          6.5       92.0  119050.0       Grumpy Old Men Collection
# 3          6.1       34.0       NaN                             NaN
# 4          5.7      173.0   96871.0  Father of the Bride Collection
#
#                         poster_path                     backdrop_path  \
# 0  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1                               NaN                               NaN
# 2  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
# 3                               NaN                               NaN
# 4  /nts4iOmNnq7GNicycMJ9pSAn204.jpg  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg
#
#           genre_id                    genre_name  \
# 0  [16, 35, 10751]   [Animation, Comedy, Family]
# 1  [12, 14, 10751]  [Adventure, Fantasy, Family]
# 2      [10749, 35]             [Romance, Comedy]
# 3  [35, 18, 10749]      [Comedy, Drama, Romance]
# 4             [35]                      [Comedy]
#
#                              production_company_name production_company_id
# 0                          [Pixar Animation Studios]                   [3]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...    [559, 2550, 10201]
# 2                     [Warner Bros., Lancaster Gate]         [6194, 19464]
# 3           [Twentieth Century Fox Film Corporation]                 [306]
# 4       [Sandollar Productions, Touchstone Pictures]          [5842, 9195]
#
# [5 rows x 31 columns]

# %% [markdown]
# ### production_countries
#
# Lo mismo aquí tal cual como para `production_company`

# %%
dataframe_from_col4 = pd.DataFrame(columns=['production_iso_3166_1','production_country'])

for value in result_dataframe["production_countries"]:
    if pd.notna(value):  # Check if the value is not NaN
        data = ast.literal_eval(value)
        if isinstance(data, list) and len(data) > 0:
            iso_3166_1 = [item['iso_3166_1'] for item in data]
            names = [item['name'] for item in data]
            dataframe_from_col4.loc[len(dataframe_from_col4)] = [iso_3166_1[0], names[0]]
        else:
            dataframe_from_col4.loc[len(dataframe_from_col4)] = [None, None]
    else:
        dataframe_from_col4.loc[len(dataframe_from_col4)] = [None, None]

dataframe_from_col4.head(5)
# Out:
#   production_iso_3166_1        production_country
# 0                    US  United States of America
# 1                    US  United States of America
# 2                    US  United States of America
# 3                    US  United States of America
# 4                    US  United States of America

# %%
result_dataframe=result_dataframe.join(dataframe_from_col4)
result_dataframe.head(5)
# Out:
#    adult    budget                                             genres  \
# 0  False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4  False         0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview popularity  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943  ...
# 1  When siblings Judy and Peter discover an encha...  17.015539  ...
# 2  A family wedding reignites the ancient feud be...    11.7129  ...
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495  ...
# 4  Just when George Banks has recovered from his ...   8.387519  ...
#
#          id                            name                       poster_path  \
# 0   10194.0            Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
# 1       NaN                             NaN                               NaN
# 2  119050.0       Grumpy Old Men Collection  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg
# 3       NaN                             NaN                               NaN
# 4   96871.0  Father of the Bride Collection  /nts4iOmNnq7GNicycMJ9pSAn204.jpg
#
#                       backdrop_path         genre_id  \
# 0  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg  [16, 35, 10751]
# 1                               NaN  [12, 14, 10751]
# 2  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg      [10749, 35]
# 3                               NaN  [35, 18, 10749]
# 4  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg             [35]
#
#                      genre_name  \
# 0   [Animation, Comedy, Family]
# 1  [Adventure, Fantasy, Family]
# 2             [Romance, Comedy]
# 3      [Comedy, Drama, Romance]
# 4                      [Comedy]
#
#                              production_company_name production_company_id  \
# 0                          [Pixar Animation Studios]                   [3]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...    [559, 2550, 10201]
# 2                     [Warner Bros., Lancaster Gate]         [6194, 19464]
# 3           [Twentieth Century Fox Film Corporation]                 [306]
# 4       [Sandollar Productions, Touchstone Pictures]          [5842, 9195]
#
#   production_iso_3166_1        production_country
# 0                    US  United States of America
# 1                    US  United States of America
# 2                    US  United States of America
# 3                    US  United States of America
# 4                    US  United States of America
#
# [5 rows x 33 columns]

# %% [markdown]
# ### spoken_languages
#
# Última columna por desanidar

# %%
dataframe_from_col5 = pd.DataFrame(columns=['language_iso_639_1','language'])

for value in result_dataframe["spoken_languages"]:
    if pd.notna(value):  # Check if the value is not NaN
        data = ast.literal_eval(value)
        if isinstance(data, list) and len(data) > 0:
            iso_639_1 = [item['iso_639_1'] for item in data]
            language = [item['name'] for item in data]
            dataframe_from_col5.loc[len(dataframe_from_col5)] = [iso_639_1[0], language[0]]
        else:
            dataframe_from_col5.loc[len(dataframe_from_col5)] = [None, None]
    else:
        dataframe_from_col5.loc[len(dataframe_from_col5)] = [None, None]

dataframe_from_col5.head(5)
# Out:
#   language_iso_639_1 language
# 0                 en  English
# 1                 en  English
# 2                 en  English
# 3                 en  English
# 4                 en  English

# %%
result_dataframe = result_dataframe.join(dataframe_from_col5)
result_dataframe.head(5)
# Out:
#    adult    budget                                             genres  \
# 0  False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4  False         0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview popularity  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943  ...
# 1  When siblings Judy and Peter discover an encha...  17.015539  ...
# 2  A family wedding reignites the ancient feud be...    11.7129  ...
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495  ...
# 4  Just when George Banks has recovered from his ...   8.387519  ...
#
#                         poster_path                     backdrop_path  \
# 0  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1                               NaN                               NaN
# 2  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
# 3                               NaN                               NaN
# 4  /nts4iOmNnq7GNicycMJ9pSAn204.jpg  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg
#
#           genre_id                    genre_name  \
# 0  [16, 35, 10751]   [Animation, Comedy, Family]
# 1  [12, 14, 10751]  [Adventure, Fantasy, Family]
# 2      [10749, 35]             [Romance, Comedy]
# 3  [35, 18, 10749]      [Comedy, Drama, Romance]
# 4             [35]                      [Comedy]
#
#                              production_company_name  production_company_id  \
# 0                          [Pixar Animation Studios]                    [3]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...     [559, 2550, 10201]
# 2                     [Warner Bros., Lancaster Gate]          [6194, 19464]
# 3           [Twentieth Century Fox Film Corporation]                  [306]
# 4       [Sandollar Productions, Touchstone Pictures]           [5842, 9195]
#
#   production_iso_3166_1        production_country language_iso_639_1 language
# 0                    US  United States of America                 en  English
# 1                    US  United States of America                 en  English
# 2                    US  United States of America                 en  English
# 3                    US  United States of America                 en  English
# 4                    US  United States of America                 en  English
#
# [5 rows x 35 columns]

# %%
len(result_dataframe.columns)
# Out:
# 35

# %%
result_dataframe.columns
# Out:
# Index(['adult', 'budget', 'homepage', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'revenue', 'runtime', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count', 'id', 'name', 'poster_path',
#        'backdrop_path', 'genre_id', 'genre_name', 'production_company_name',
#        'production_company_id', 'production_iso_3166_1', 'production_country',
#        'language_iso_639_1', 'language'],
#       dtype='object')

# %% [markdown]
# Ahora con las columnas desanidadas, se procede a eliminar las que contienen los datos anidados del dataframe y luego se guarda un nuevo archivo csv

# %%
result_dataframe.drop(columns=['genres','production_companies','production_countries','spoken_languages'],axis=1, inplace=True)
len(result_dataframe.columns)
# Out:
# 31

# %%
result_dataframe.columns
# Out:
# Index(['adult', 'budget', 'homepage', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'revenue', 'runtime', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count', 'id', 'name', 'poster_path',
#        'backdrop_path', 'genre_id', 'genre_name', 'production_company_name',
#        'production_company_id', 'production_iso_3166_1', 'production_country',
#        'language_iso_639_1', 'language'],
#       dtype='object')

# %% [markdown]
# ### Filling and dropping null or NaN values
#
# Ahora se manejan los datos faltantes

# %%
result_dataframe.fillna({"revenue":0,"budget":0},inplace=True)

# %%
result_dataframe.isna().sum()
# Out:
# adult                          0
# budget                         0
# homepage                   37684
# id                             0
# imdb_id                       17
# original_language             11
# original_title                 0
# overview                     954
# popularity                     5
# poster_path                  386
# release_date                  87
# revenue                        0
# runtime                      263
# status                        87
# tagline                    25054
# title                          6
# video                          6
# vote_average                   6
# vote_count                     6
# id                         40975
# name                       40975
# poster_path                41518
# backdrop_path              42203
# genre_id                       0
# genre_name                     0
# production_company_name    11881
# production_company_id      11881
# production_iso_3166_1       6288
# production_country          6288
# language_iso_639_1          3835
# language                    3835
# dtype: int64

# %%
result_dataframe.dropna(subset=["release_date"], inplace=True)

# %%
result_dataframe.isna().sum()
# Out:
# adult                          0
# budget                         0
# homepage                   37610
# id                             0
# imdb_id                       14
# original_language             11
# original_title                 0
# overview                     941
# popularity                     2
# poster_path                  339
# release_date                   0
# revenue                        0
# runtime                      249
# status                        83
# tagline                    24981
# title                          3
# video                          3
# vote_average                   3
# vote_count                     3
# id                         40891
# name                       40891
# poster_path                41434
# backdrop_path              42119
# genre_id                       0
# genre_name                     0
# production_company_name    11799
# production_company_id      11799
# production_iso_3166_1       6214
# production_country          6214
# language_iso_639_1          3771
# language                    3771
# dtype: int64

# %%
result_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45379 entries, 0 to 45465
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   adult                    45379 non-null  object
#  1   budget                   45379 non-null  object
#  2   homepage                 7769 non-null   object
#  3   id                       45379 non-null  object
#  4   imdb_id                  45365 non-null  object
#  5   original_language        45368 non-null  object
#  6   original_title           45379 non-null  object
#  7   overview                 44438 non-null  object
#  8   popularity               45377 non-null  object
#  9   poster_path              45040 non-null  object
#  10  release_date             45379 non-null  object
#  11  revenue                  45379 non-null  float64
#  12  runtime                  45130 non-null  float64
#  13  status                   45296 non-null  object
#  14  tagline                  20398 non-null  object
#  15  title                    45376 non-null  object
#  16  video                    45376 non-null  object
#  17  vote_average             45376 non-null  float64
#  18  vote_count               45376 non-null  float64
#  19  id                       4488 non-null   float64
#  20  name                     4488 non-null   object
#  21  poster_path              3945 non-null   object
#  22  backdrop_path            3260 non-null   object
#  23  genre_id                 45379 non-null  object
#  24  genre_name               45379 non-null  object
#  25  production_company_name  33580 non-null  object
#  26  production_company_id    33580 non-null  object
#  27  production_iso_3166_1    39165 non-null  object
#  28  production_country       39165 non-null  object
#  29  language_iso_639_1       41608 non-null  object
#  30  language                 41608 non-null  object
# dtypes: float64(5), object(26)
# memory usage: 11.1+ MB

# %%
data_copy = result_dataframe.copy()

# %%
data_copy['release_date'] = pd.to_datetime(data_copy['release_date'], errors='coerce')

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45379 entries, 0 to 45465
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   adult                    45379 non-null  object
#  1   budget                   45379 non-null  object
#  2   homepage                 7769 non-null   object
#  3   id                       45379 non-null  object
#  4   imdb_id                  45365 non-null  object
#  5   original_language        45368 non-null  object
#  6   original_title           45379 non-null  object
#  7   overview                 44438 non-null  object
#  8   popularity               45377 non-null  object
#  9   poster_path              45040 non-null  object
#  10  release_date             45376 non-null  datetime64[ns]
#  11  revenue                  45379 non-null  float64
#  12  runtime                  45130 non-null  float64
#  13  status                   45296 non-null  object
#  14  tagline                  20398 non-null  object
#  15  title                    45376 non-null  object
#  16  video                    45376 non-null  object
#  17  vote_average             45376 non-null  float64
#  18  vote_count               45376 non-null  float64
#  19  id                       4488 non-null   float64
#  20  name                     4488 non-null   object
#  21  poster_path              3945 non-null   object
#  22  backdrop_path            3260 non-null   object
#  23  genre_id                 45379 non-null  object
#  24  genre_name               45379 non-null  object
#  25  production_company_name  33580 non-null  object
#  26  production_company_id    33580 non-null  object
#  27  production_iso_3166_1    39165 non-null  object
#  28  production_country       39165 non-null  object
#  29  language_iso_639_1       41608 non-null  object
#  30  language                 41608 non-null  object
#  31  release_year             45376 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(25)
# memory usage: 12.4+ MB

# %%
data_copy["release_year"] = data_copy["release_date"].dt.year
data_copy.dropna(subset=["release_year"],inplace=True)

# %%
data_copy["release_year"] = data_copy["release_year"].astype(int)
data_copy
# Out:
#        adult    budget                              homepage      id  \
# 0      False  30000000  http://toystory.disney.com/toy-story     862
# 1      False  65000000                                   NaN    8844
# 2      False         0                                   NaN   15602
# 3      False  16000000                                   NaN   31357
# 4      False         0                                   NaN   11862
# ...      ...       ...                                   ...     ...
# 45460  False         0                                   NaN   30840
# 45462  False         0                                   NaN  111109
# 45463  False         0                                   NaN   67758
# 45464  False         0                                   NaN  227506
# 45465  False         0                                   NaN  461257
#
#          imdb_id original_language               original_title  \
# 0      tt0114709                en                    Toy Story
# 1      tt0113497                en                      Jumanji
# 2      tt0113228                en             Grumpier Old Men
# 3      tt0114885                en            Waiting to Exhale
# 4      tt0113041                en  Father of the Bride Part II
# ...          ...               ...                          ...
# 45460  tt0102797                en                   Robin Hood
# 45462  tt2028550                tl          Siglo ng Pagluluwal
# 45463  tt0303758                en                     Betrayal
# 45464  tt0008536                en          Satana likuyushchiy
# 45465  tt6980792                en                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45460  Yet another version of the classic epic, with ...   5.683753
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  ...  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...
# ...                                 ...  ...
# 45460  /fQC46NglNiEMZBv5XHoyLuOWoN5.jpg  ...
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg  ...
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg  ...
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg  ...
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg  ...
#
#                           backdrop_path         genre_id  \
# 0      /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg  [16, 35, 10751]
# 1                                   NaN  [12, 14, 10751]
# 2      /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg      [10749, 35]
# 3                                   NaN  [35, 18, 10749]
# 4      /7qwE57OVZmMJChBpLEbJEmzUydk.jpg             [35]
# ...                                 ...              ...
# 45460                               NaN  [18, 28, 10749]
# 45462                               NaN             [18]
# 45463                               NaN     [28, 18, 53]
# 45464                               NaN               []
# 45465                               NaN               []
#
#                          genre_name  \
# 0       [Animation, Comedy, Family]
# 1      [Adventure, Fantasy, Family]
# 2                 [Romance, Comedy]
# 3          [Comedy, Drama, Romance]
# 4                          [Comedy]
# ...                             ...
# 45460      [Drama, Action, Romance]
# 45462                       [Drama]
# 45463     [Action, Drama, Thriller]
# 45464                            []
# 45465                            []
#
#                                  production_company_name  \
# 0                              [Pixar Animation Studios]
# 1      [TriStar Pictures, Teitler Film, Interscope Co...
# 2                         [Warner Bros., Lancaster Gate]
# 3               [Twentieth Century Fox Film Corporation]
# 4           [Sandollar Productions, Touchstone Pictures]
# ...                                                  ...
# 45460  [Westdeutscher Rundfunk (WDR), Working Title F...
# 45462                                      [Sine Olivia]
# 45463                          [American World Pictures]
# 45464                                        [Yermoliev]
# 45465                                               None
#
#              production_company_id production_iso_3166_1  \
# 0                              [3]                    US
# 1               [559, 2550, 10201]                    US
# 2                    [6194, 19464]                    US
# 3                            [306]                    US
# 4                     [5842, 9195]                    US
# ...                            ...                   ...
# 45460  [7025, 10163, 16323, 38978]                    CA
# 45462                      [19653]                    PH
# 45463                       [6165]                    US
# 45464                      [88753]                    RU
# 45465                         None                    GB
#
#              production_country  language_iso_639_1  language  release_year
# 0      United States of America                  en   English          1995
# 1      United States of America                  en   English          1995
# 2      United States of America                  en   English          1995
# 3      United States of America                  en   English          1995
# 4      United States of America                  en   English          1995
# ...                         ...                 ...       ...           ...
# 45460                    Canada                  en   English          1991
# 45462               Philippines                  tl                    2011
# 45463  United States of America                  en   English          2003
# 45464                    Russia                None      None          1917
# 45465            United Kingdom                  en   English          2017
#
# [45376 rows x 32 columns]

# %%
unnested_data = pd.read_csv("movies_dataset_unnested.csv")
unnested_data.tail(5)
# Out:
# /tmp/ipykernel_11909/3206048439.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   unnested_data = pd.read_csv("movies_dataset_unnested.csv")
#        adult budget                              homepage      id    imdb_id  \
# 45461  False      0  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462  False      0                                   NaN  111109  tt2028550
# 45463  False      0                                   NaN   67758  tt0303758
# 45464  False      0                                   NaN  227506  tt0008536
# 45465  False      0                                   NaN  461257  tt6980792
#
#       original_language       original_title  \
# 45461                fa              رگ خواب
# 45462                tl  Siglo ng Pagluluwal
# 45463                en             Betrayal
# 45464                en  Satana likuyushchiy
# 45465                en             Queerama
#
#                                                 overview popularity  \
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  ... poster_path.1  backdrop_path  \
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg  ...           NaN            NaN
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg  ...           NaN            NaN
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg  ...           NaN            NaN
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg  ...           NaN            NaN
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg  ...           NaN            NaN
#
#            genre_id                       genre_name  \
# 45461   [18, 10751]              ['Drama', 'Family']
# 45462          [18]                        ['Drama']
# 45463  [28, 18, 53]  ['Action', 'Drama', 'Thriller']
# 45464            []                               []
# 45465            []                               []
#
#            production_company_name production_company_id  \
# 45461                          NaN                   NaN
# 45462              ['Sine Olivia']               [19653]
# 45463  ['American World Pictures']                [6165]
# 45464                ['Yermoliev']               [88753]
# 45465                          NaN                   NaN
#
#       production_iso_3166_1        production_country  language_iso_639_1  \
# 45461                    IR                      Iran                  fa
# 45462                    PH               Philippines                  tl
# 45463                    US  United States of America                  en
# 45464                    RU                    Russia                 NaN
# 45465                    GB            United Kingdom                  en
#
#        language
# 45461     فارسی
# 45462       NaN
# 45463   English
# 45464       NaN
# 45465   English
#
# [5 rows x 31 columns]

# %%
non_numeric = pd.to_numeric(unnested_data["budget"],errors='coerce')
unnested_data[non_numeric.isna()]
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#                                  budget  \
# 19730  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# 35587           [{'iso_3166_1': 'CA', 'name': 'Canada'}]  2014-01-01       0
#
#       original_language                            original_title  overview  \
# 19730             104.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 29503              68.0      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 35587              82.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                   popularity                          poster_path  ...  \
# 19730                    NaN                         Midnight Man  ...
# 29503                    NaN  Mardock Scramble: The Third Exhaust  ...
# 35587  Beware Of Frost Bites                     Avalanche Sharks  ...
#
#       poster_path.1  backdrop_path                         genre_id  \
# 19730           NaN            NaN            [11176, 11602, 29812]
# 29503           NaN            NaN  [2883, 7759, 7760, 7761, 33751]
# 35587           NaN            NaN     [17161, 18012, 18013, 23822]
#
#                                               genre_name  \
# 19730  ['Carousel Productions', 'Vision View Entertai...
# 29503  ['Aniplex', 'GoHands', 'BROSTA TV', 'Mardock S...
# 35587  ['Odyssey Media', 'Pulser Productions', 'Rogue...
#
#       production_company_name production_company_id production_iso_3166_1  \
# 19730                     NaN                   NaN                   NaN
# 29503                     NaN                   NaN                   NaN
# 35587                     NaN                   NaN                   NaN
#
#        production_country  language_iso_639_1  language
# 19730                 NaN                 NaN       NaN
# 29503                 NaN                 NaN       NaN
# 35587                 NaN                 NaN       NaN
#
# [3 rows x 31 columns]

# %%
unnested_data_without_nan = unnested_data[non_numeric.notna()]
unnested_data_without_nan
# Out:
#        adult    budget                              homepage      id  \
# 0      False  30000000  http://toystory.disney.com/toy-story     862
# 1      False  65000000                                   NaN    8844
# 2      False         0                                   NaN   15602
# 3      False  16000000                                   NaN   31357
# 4      False         0                                   NaN   11862
# ...      ...       ...                                   ...     ...
# 45461  False         0  http://www.imdb.com/title/tt6209470/  439050
# 45462  False         0                                   NaN  111109
# 45463  False         0                                   NaN   67758
# 45464  False         0                                   NaN  227506
# 45465  False         0                                   NaN  461257
#
#          imdb_id original_language               original_title  \
# 0      tt0114709                en                    Toy Story
# 1      tt0113497                en                      Jumanji
# 2      tt0113228                en             Grumpier Old Men
# 3      tt0114885                en            Waiting to Exhale
# 4      tt0113041                en  Father of the Bride Part II
# ...          ...               ...                          ...
# 45461  tt6209470                fa                      رگ خواب
# 45462  tt2028550                tl          Siglo ng Pagluluwal
# 45463  tt0303758                en                     Betrayal
# 45464  tt0008536                en          Satana likuyushchiy
# 45465  tt6980792                en                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  ...  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...
# ...                                 ...  ...
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg  ...
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg  ...
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg  ...
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg  ...
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg  ...
#
#                           poster_path.1                     backdrop_path  \
# 0      /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1                                   NaN                               NaN
# 2      /nLvUdqgPgm3F85NMCii9gVFUcet.jpg  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
# 3                                   NaN                               NaN
# 4      /nts4iOmNnq7GNicycMJ9pSAn204.jpg  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg
# ...                                 ...                               ...
# 45461                               NaN                               NaN
# 45462                               NaN                               NaN
# 45463                               NaN                               NaN
# 45464                               NaN                               NaN
# 45465                               NaN                               NaN
#
#               genre_id                          genre_name  \
# 0      [16, 35, 10751]   ['Animation', 'Comedy', 'Family']
# 1      [12, 14, 10751]  ['Adventure', 'Fantasy', 'Family']
# 2          [10749, 35]               ['Romance', 'Comedy']
# 3      [35, 18, 10749]      ['Comedy', 'Drama', 'Romance']
# 4                 [35]                          ['Comedy']
# ...                ...                                 ...
# 45461      [18, 10751]                 ['Drama', 'Family']
# 45462             [18]                           ['Drama']
# 45463     [28, 18, 53]     ['Action', 'Drama', 'Thriller']
# 45464               []                                  []
# 45465               []                                  []
#
#                                  production_company_name  \
# 0                            ['Pixar Animation Studios']
# 1      ['TriStar Pictures', 'Teitler Film', 'Intersco...
# 2                     ['Warner Bros.', 'Lancaster Gate']
# 3             ['Twentieth Century Fox Film Corporation']
# 4       ['Sandollar Productions', 'Touchstone Pictures']
# ...                                                  ...
# 45461                                                NaN
# 45462                                    ['Sine Olivia']
# 45463                        ['American World Pictures']
# 45464                                      ['Yermoliev']
# 45465                                                NaN
#
#       production_company_id production_iso_3166_1        production_country  \
# 0                       [3]                    US  United States of America
# 1        [559, 2550, 10201]                    US  United States of America
# 2             [6194, 19464]                    US  United States of America
# 3                     [306]                    US  United States of America
# 4              [5842, 9195]                    US  United States of America
# ...                     ...                   ...                       ...
# 45461                   NaN                    IR                      Iran
# 45462               [19653]                    PH               Philippines
# 45463                [6165]                    US  United States of America
# 45464               [88753]                    RU                    Russia
# 45465                   NaN                    GB            United Kingdom
#
#        language_iso_639_1  language
# 0                      en   English
# 1                      en   English
# 2                      en   English
# 3                      en   English
# 4                      en   English
# ...                   ...       ...
# 45461                  fa     فارسی
# 45462                  tl       NaN
# 45463                  en   English
# 45464                 NaN       NaN
# 45465                  en   English
#
# [45463 rows x 31 columns]

# %%
unnested_data_without_nan["budget"] = unnested_data_without_nan["budget"].astype(int)
unnested_data_without_nan["budget"]
# Out:
# /tmp/ipykernel_11909/3253403878.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unnested_data_without_nan["budget"] = unnested_data_without_nan["budget"].astype(int)
# 0        30000000
# 1        65000000
# 2               0
# 3        16000000
# 4               0
#            ...
# 45461           0
# 45462           0
# 45463           0
# 45464           0
# 45465           0
# Name: budget, Length: 45463, dtype: int64

# %%
unnested_data_without_nan["return"] = unnested_data_without_nan["revenue"].div(unnested_data_without_nan["budget"]).replace(np.nan,0).replace(np.inf,0)
unnested_data_without_nan["return"]
# Out:
# /tmp/ipykernel_11909/1090359219.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unnested_data_without_nan["return"] = unnested_data_without_nan["revenue"].div(unnested_data_without_nan["budget"]).replace(np.nan,0).replace(np.inf,0)
# 0        12.451801
# 1         4.043035
# 2         0.000000
# 3         5.090760
# 4         0.000000
#            ...
# 45461     0.000000
# 45462     0.000000
# 45463     0.000000
# 45464     0.000000
# 45465     0.000000
# Name: return, Length: 45463, dtype: float64

# %%
final_movies_dataset = unnested_data_without_nan.copy()
final_movies_dataset.columns
# Out:
# Index(['adult', 'budget', 'homepage', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'revenue', 'runtime', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count', 'id.1', 'name', 'poster_path.1',
#        'backdrop_path', 'genre_id', 'genre_name', 'production_company_name',
#        'production_company_id', 'production_iso_3166_1', 'production_country',
#        'language_iso_639_1', 'language', 'return'],
#       dtype='object')

# %%
final_movies_dataset.drop(columns=['video','imdb_id','adult','original_title','poster_path','homepage'],axis=1,inplace=True)
final_movies_dataset.columns
# Out:
# Index(['budget', 'id', 'original_language', 'overview', 'popularity',
#        'release_date', 'revenue', 'runtime', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'id.1', 'name', 'poster_path.1',
#        'backdrop_path', 'genre_id', 'genre_name', 'production_company_name',
#        'production_company_id', 'production_iso_3166_1', 'production_country',
#        'language_iso_639_1', 'language', 'return'],
#       dtype='object')

# %%
final_movies_dataset.to_csv("movies_dataset_final.csv",index=False)

# %%
# remove duplicated

df = pd.read_csv("movies_dataset_final.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   budget                   45463 non-null  int64
#  1   id                       45463 non-null  int64
#  2   original_language        45452 non-null  object
#  3   overview                 44509 non-null  object
#  4   popularity               45460 non-null  float64
#  5   release_date             45376 non-null  object
#  6   revenue                  45460 non-null  float64
#  7   runtime                  45203 non-null  float64
#  8   status                   45379 non-null  object
#  9   tagline                  20412 non-null  object
#  10  title                    45460 non-null  object
#  11  vote_average             45460 non-null  float64
#  12  vote_count               45460 non-null  float64
#  13  id.1                     4491 non-null   float64
#  14  name                     4491 non-null   object
#  15  poster_path.1            3948 non-null   object
#  16  backdrop_path            3263 non-null   object
#  17  genre_id                 45463 non-null  object
#  18  genre_name               45463 non-null  object
#  19  production_company_name  33585 non-null  object
#  20  production_company_id    33585 non-null  object
#  21  production_iso_3166_1    39177 non-null  object
#  22  production_country       39178 non-null  object
#  23  language_iso_639_1       41631 non-null  object
#  24  language                 41410 non-null  object
#  25  return                   45463 non-null  float64
# dtypes: float64(7), int64(2), object(17)
# memory usage: 9.0+ MB

# %%
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45446 entries, 0 to 45462
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   budget                   45446 non-null  int64
#  1   id                       45446 non-null  int64
#  2   original_language        45435 non-null  object
#  3   overview                 44492 non-null  object
#  4   popularity               45443 non-null  float64
#  5   release_date             45359 non-null  object
#  6   revenue                  45443 non-null  float64
#  7   runtime                  45186 non-null  float64
#  8   status                   45362 non-null  object
#  9   tagline                  20407 non-null  object
#  10  title                    45443 non-null  object
#  11  vote_average             45443 non-null  float64
#  12  vote_count               45443 non-null  float64
#  13  id.1                     4490 non-null   float64
#  14  name                     4490 non-null   object
#  15  poster_path.1            3947 non-null   object
#  16  backdrop_path            3263 non-null   object
#  17  genre_id                 45446 non-null  object
#  18  genre_name               45446 non-null  object
#  19  production_company_name  33573 non-null  object
#  20  production_company_id    33573 non-null  object
#  21  production_iso_3166_1    39163 non-null  object
#  22  production_country       39164 non-null  object
#  23  language_iso_639_1       41616 non-null  object
#  24  language                 41395 non-null  object
#  25  return                   45446 non-null  float64
# dtypes: float64(7), int64(2), object(17)
# memory usage: 9.4+ MB

# %%
df.to_csv("movies_dataset_cleaned.csv",index=False)
